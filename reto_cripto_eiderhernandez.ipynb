# %% [markdown]
# <a href="https://colab.research.google.com/github/EiderHernandezProgramacion/Lenguajes-de-programacion/blob/main/reto_cripto_eiderhernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Reto Cripto · Concurso Analítica Financiera
# _Notebook generado por Eiderhernandez en EduApp ITM_

# %%
# !pip install yfinance pandas plotly

# %%
import yfinance as yf
import pandas as pd
import plotly.express as px

# %%
btc = yf.download"BTC-USD", start="2024-01-01", end="2024-12-31", interval="1d")
btc.head()

# %% [markdown]
# ## 🐼 Inspección con pandas

# %%
btc.shape

# %% [markdown]
# ## 📈 Visualización con Plotly

# %%
fig = px.line(btc, x=btc.index, y="Close", title="BTC-USD 2024")
fig.show()

# %% [markdown]
# ## 🔥 Análisis multi-cripto

# %%
# Descarga 4 criptos y compara su rendimiento %
tickers = ["BTC-USD", "ETH-USD", "SOL-USD", "ADA-USD"]
data = yf.download(tickers, start="2024-01-01")["Close"]
rend = (data.iloc[-1] / data.iloc[0] - 1) * 100
print(rend.sort_values(ascending=False))
