# %% [markdown]
# <a href="https://colab.research.google.com/github/EiderHernandezProgramacion/Lenguajes-de-programacion/blob/main/Copia_de_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Celda 1: instalar y importar
# !pip install yfinance --quiet
import yfinance as yf
import pandas as pd
import numpy as np

print("¡Listo para analizar cripto!")
# Out:
# ¡Listo para analizar cripto!

# %%
import yfinance as yf

btc = yf.download(
    'BTC-USD',
    start='2024-01-01',
    end='2024-12-31',
    interval='1d'
)
# Out:
# /tmp/ipykernel_31615/3392092657.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download(
# [*********************100%***********************]  1 of 1 completed
